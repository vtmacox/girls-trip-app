# %%
import requests

url = "https://api.travelpayouts.com/v1/prices/direct"

querystring = {"origin":"BOS","destination":"SEA","depart_date":"2025-07-01","return_date":"2025-07", "currency":"usd"}

headers = {'x-access-token': '321d6a221f8926b5ec41ae89a3b2ae7b'}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"data":{},"currency":"usd","success":true}
